# %%
# %cd ../section5
# %run 'sample_code_c5_1.py'
# Out:
# /Users/niwa/src/python_source_separation/section5

# %%
import IPython.display as ipd
ipd.Audio('conv_out.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %run 'sample_code_c5_2.py'

# %%
ipd.Audio('conv_out_0.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio('conv_out_1.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %run 'sample_code_c5_3.py'
